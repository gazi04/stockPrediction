# %%
name = dbutils.widgets.get("name")
message = f"Don't worry {name}, I got your request! Welcome to prefect-databricks!"
print(message)

# %%
# %sql

select count(*) from stock_prediction.default.stocks;
